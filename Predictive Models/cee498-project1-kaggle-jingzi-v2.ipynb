# %% [markdown]
# # The Regular Neural Network for the Prediction of Bike Sharing

# %% [markdown]
# The goal of the project is to predict the ranges of cnt (the count of a new bike shares) each hour based on the given factors. To achieve this goal, a regular neural network based on tensorflow is designed.

# %% [markdown]
# First of all, several essential packages and training data are imported. The data is from https://www.kaggle.com/c/cee-498-project1-london-bike-sharing

# %%
import numpy as np
import tensorflow as tf
import pandas as pd

# %%
df = pd.read_csv("../input/cee-498-project1-london-bike-sharing/train.csv")
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 1      2015-01-04 07:00:00    75  1.0 -1.0  100.0         7.0           4.0
# 2      2015-01-04 08:00:00   131  1.5 -1.0   96.5         8.0           4.0
# 3      2015-01-04 09:00:00   301  2.0 -0.5  100.0         9.0           3.0
# 4      2015-01-04 10:00:00   528  3.0 -0.5   93.0        12.0           3.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 12218  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 12219  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 12220  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 12221  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 12222  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 12218         0.0         0.0     3.0
# 12219         0.0         0.0     3.0
# 12220         0.0         0.0     3.0
# 12221         0.0         0.0     3.0
# 12222         0.0         0.0     3.0
#
# [12223 rows x 10 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# In data preprocessing, split "timestamp" to "year", "month", "day" and "hour". Besides, "t1" is deleted because "t1" and "t2" are highly correlated.

# %%
df.dropna(axis=0, how='any')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['year'] = df['timestamp'].dt.year
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df['hour'] = df['timestamp'].dt.hour
df = df.drop(['timestamp','t1'], axis=1)
df
# Out:
#         cnt   t2    hum  wind_speed  weather_code  is_holiday  is_weekend  \
# 0       134  2.5   96.5         0.0           1.0         0.0         1.0
# 1        75 -1.0  100.0         7.0           4.0         0.0         1.0
# 2       131 -1.0   96.5         8.0           4.0         0.0         1.0
# 3       301 -0.5  100.0         9.0           3.0         0.0         1.0
# 4       528 -0.5   93.0        12.0           3.0         0.0         1.0
# ...     ...  ...    ...         ...           ...         ...         ...
# 12218  1042  1.0   81.0        19.0           3.0         0.0         0.0
# 12219   541  1.0   81.0        21.0           4.0         0.0         0.0
# 12220   337  1.5   78.5        24.0           4.0         0.0         0.0
# 12221   224  1.5   76.0        23.0           4.0         0.0         0.0
# 12222   139  1.0   76.0        22.0           2.0         0.0         0.0
#
#        season  year  month  day  hour
# 0         3.0  2015      1    4     2
# 1         3.0  2015      1    4     7
# 2         3.0  2015      1    4     8
# 3         3.0  2015      1    4     9
# 4         3.0  2015      1    4    10
# ...       ...   ...    ...  ...   ...
# 12218     3.0  2017      1    3    19
# 12219     3.0  2017      1    3    20
# 12220     3.0  2017      1    3    21
# 12221     3.0  2017      1    3    22
# 12222     3.0  2017      1    3    23
#
# [12223 rows x 12 columns]

# %% [markdown]
# Assign columns to dataset in the type of tensorflow. "cnt" is the target and the other columns are factors.

# %%
cnt = df.pop('cnt')
dataset = tf.data.Dataset.from_tensor_slices((df.values, cnt.values))

# %%
for feat, targ in dataset.take(5):
  print ('Features: {}, Target: {}'.format(feat, targ))
# Out:
# Features: [2.500e+00 9.650e+01 0.000e+00 1.000e+00 0.000e+00 1.000e+00 3.000e+00
#  2.015e+03 1.000e+00 4.000e+00 2.000e+00], Target: 134
# Features: [-1.000e+00  1.000e+02  7.000e+00  4.000e+00  0.000e+00  1.000e+00
#   3.000e+00  2.015e+03  1.000e+00  4.000e+00  7.000e+00], Target: 75
# Features: [-1.000e+00  9.650e+01  8.000e+00  4.000e+00  0.000e+00  1.000e+00
#   3.000e+00  2.015e+03  1.000e+00  4.000e+00  8.000e+00], Target: 131
# Features: [-5.000e-01  1.000e+02  9.000e+00  3.000e+00  0.000e+00  1.000e+00
#   3.000e+00  2.015e+03  1.000e+00  4.000e+00  9.000e+00], Target: 301
# Features: [-5.000e-01  9.300e+01  1.200e+01  3.000e+00  0.000e+00  1.000e+00
#   3.000e+00  2.015e+03  1.000e+00  4.000e+00  1.000e+01], Target: 528

# %% [markdown]
# The training dataset is splited to mini batches.

# %%
train_dataset = dataset.shuffle(len(df)).batch(batch_size=150).repeat(20)

# %%
for feat, targ in train_dataset.take(1):
  print ('Features: {}, Target: {}'.format(feat, targ))
# Out:
# Features: [[14.  88.  24.  ... 10.  22.   2. ]
#  [ 3.5 87.   6.5 ... 11.  11.   7. ]
#  [17.5 91.   2.  ...  6.  20.  18. ]
#  ...
#  [14.  72.  17.  ...  5.  17.  22. ]
#  [ 8.  88.  12.  ... 10.  13.   8. ]
#  [ 3.  76.   7.  ...  2.  11.  12. ]], Target: [  68 1967 1039 2520  466 1455   68  594  152   35 4034  594 1263  562
#   408 1154  171 1322  617  720  109   74  650 1733  186 1824 2553 1788
#   579  105   98 1104 1735  121 2289 1805 2636 3913 1896 5008 2828  387
#   120  853  204 1739 1721  585 2059 1228  623  121  351  840 3916  150
#  1363 1499  493  129  176 1911  918  514  334  302  982   58 1709 2524
#    52 1129  453  563 1555 1485   39  739 4953  852 4470 2754 2876  780
#   120 3680 1708 1160 1530 3027  592 1544  154   62  572  964   46  992
#   307  607 2244 2037 5117 1086  169  727  738  295  146  966 1010  101
#   511  208 1208  210   93 1071 1771  166 2488 1076 2761 2013  381 4133
#  2710 1751  310 2675 1469  282 1060 1482  975   66   60 4323  143 1399
#   872 2053  478 1578  269  822 2437  640 4196  924]

# %% [markdown]
# ## The Archtecture of Model

# %% [markdown]
# The layers are shown as follow. The loss is defined by mean square error. The learning rate will be changed by epoches during the training.

# %%
model = tf.keras.Sequential(
    [tf.keras.layers.Dense(units=32, input_shape=(11,)),
     tf.keras.layers.BatchNormalization(),
     tf.keras.layers.Dense(64, activation='relu'),
     tf.keras.layers.BatchNormalization(),
     tf.keras.layers.Dense(128, activation='relu'),
     tf.keras.layers.BatchNormalization(),
     tf.keras.layers.Dense(64, activation='relu'),
     tf.keras.layers.BatchNormalization(),
     tf.keras.layers.Dense(1)
    ])

model.compile(
     optimizer=tf.keras.optimizers.Adam(lr=0.001),
     loss='mean_squared_error',
    )

def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * tf.math.exp(-0.1)**(epoch//4-2)

callback = [tf.keras.callbacks.LearningRateScheduler(scheduler),
            tf.keras.callbacks.EarlyStopping(monitor='loss',
                                             min_delta=0, patience=32,
                                             mode='min', restore_best_weights=True)]

history = model.fit(train_dataset, epochs=150, callbacks=[callback])
# Out:
# Epoch 1/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 1900981.8750
# Epoch 2/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 566026.8750
# Epoch 3/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 195450.5469
# Epoch 4/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 170516.1719
# Epoch 5/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 156681.5469
# Epoch 6/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 155947.4062
# Epoch 7/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 142627.8594
# Epoch 8/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 136128.7500
# Epoch 9/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 134841.3594
# Epoch 10/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 128986.2891
# Epoch 11/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 124697.5078
# Epoch 12/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 116238.5156
# Epoch 13/150
# 1640/1640 [==============================] - 7s 5ms/step - loss: 113248.7031
# Epoch 14/150
# 1640/1640 [==============================] - 8s 5ms/step - loss: 105056.5000
# Epoch 15/150
# 1640/1640 [==============================] - 8s 5ms/step - loss: 97944.7344
# Epoch 16/150
# 1640/1640 [==============================] - 8s 5ms/step - loss: 93344.1641
# Epoch 17/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 90297.2031
# Epoch 18/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 82866.6797
# Epoch 19/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 77233.1250
# Epoch 20/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 75495.2578
# Epoch 21/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 73447.9922
# Epoch 22/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 69727.9375
# Epoch 23/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 67409.8281
# Epoch 24/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 66768.0078
# Epoch 25/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64949.3867
# Epoch 26/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 65423.8828
# Epoch 27/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63896.0508
# Epoch 28/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63322.3477
# Epoch 29/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63927.2500
# Epoch 30/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64311.0820
# Epoch 31/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64648.6328
# Epoch 32/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 64322.0312
# Epoch 33/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 65956.3438
# Epoch 34/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63918.1602
# Epoch 35/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64694.5859
# Epoch 36/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62992.5781
# Epoch 37/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62938.3672
# Epoch 38/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63291.8086
# Epoch 39/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62931.7617
# Epoch 40/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64181.1094
# Epoch 41/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63768.6758
# Epoch 42/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62911.9492
# Epoch 43/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62887.0078
# Epoch 44/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64175.2695
# Epoch 45/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63042.6992
# Epoch 46/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62078.4023
# Epoch 47/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63131.5859
# Epoch 48/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 65519.6289
# Epoch 49/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62588.4453
# Epoch 50/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 64610.0664
# Epoch 51/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63472.5703
# Epoch 52/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 61862.6172
# Epoch 53/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62050.9609
# Epoch 54/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 65554.6719
# Epoch 55/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62955.7461
# Epoch 56/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64675.6523
# Epoch 57/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63098.4844
# Epoch 58/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63683.3672
# Epoch 59/150
# 1640/1640 [==============================] - 8s 5ms/step - loss: 60615.5820
# Epoch 60/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64290.0938
# Epoch 61/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62876.2969
# Epoch 62/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62668.3633
# Epoch 63/150
# 1640/1640 [==============================] - 8s 5ms/step - loss: 64008.7383
# Epoch 64/150
# 1640/1640 [==============================] - 8s 5ms/step - loss: 63834.3867
# Epoch 65/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63548.4375
# Epoch 66/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64779.4492
# Epoch 67/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63745.9180
# Epoch 68/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62851.0508
# Epoch 69/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 64749.3906
# Epoch 70/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63354.6602
# Epoch 71/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63831.0156
# Epoch 72/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 64119.7148
# Epoch 73/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 65563.5703
# Epoch 74/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62648.3359
# Epoch 75/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 61240.8320
# Epoch 76/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63086.8828
# Epoch 77/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63203.3984
# Epoch 78/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 65070.8555
# Epoch 79/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63551.3164
# Epoch 80/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62938.6758
# Epoch 81/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 65584.2422
# Epoch 82/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 64029.7031
# Epoch 83/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63185.4648
# Epoch 84/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62429.5000
# Epoch 85/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63347.7891
# Epoch 86/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 62760.8203
# Epoch 87/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 62462.1992
# Epoch 88/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 61961.6914
# Epoch 89/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 61404.1523
# Epoch 90/150
# 1640/1640 [==============================] - 6s 4ms/step - loss: 63407.6211
# Epoch 91/150
# 1640/1640 [==============================] - 7s 4ms/step - loss: 63886.9023

# %% [markdown]
# ## The Test of Model

# %% [markdown]
# Import test data to test the accuracy of the model.
#
# The performance of the neural network is evaluated based on the RMSE of predictions.

# %%
df2 = pd.read_csv("../input/cee-498-project1-london-bike-sharing/test.csv")
df2.dropna(axis=0, how='any')
df2['timestamp'] = pd.to_datetime(df2['timestamp'])
df2['year'] = df2['timestamp'].dt.year
df2['month'] = df2['timestamp'].dt.month
df2['day'] = df2['timestamp'].dt.day
df2['hour'] = df2['timestamp'].dt.hour
df_test = df2.drop(['timestamp','t1'], axis=1)
df_test
# Out:
#        t2    hum  wind_speed  weather_code  is_holiday  is_weekend  season  \
# 0     2.0   93.0         6.0           3.0         0.0         1.0     3.0
# 1     2.5   93.0         5.0           1.0         0.0         1.0     3.0
# 2     2.0  100.0         0.0           1.0         0.0         1.0     3.0
# 3     0.0   93.0         6.5           1.0         0.0         1.0     3.0
# 4     2.0   93.0         4.0           1.0         0.0         1.0     3.0
# ...   ...    ...         ...           ...         ...         ...     ...
# 5186  2.5   76.0        11.0           1.0         1.0         0.0     3.0
# 5187  0.0   81.0        11.0           1.0         1.0         0.0     3.0
# 5188 -1.5   81.0        14.0           1.0         0.0         0.0     3.0
# 5189  0.0   78.0        21.0           1.0         0.0         0.0     3.0
# 5190  1.0   81.0        22.0           2.0         0.0         0.0     3.0
#
#       year  month  day  hour
# 0     2015      1    4     0
# 1     2015      1    4     1
# 2     2015      1    4     3
# 3     2015      1    4     4
# 4     2015      1    4     5
# ...    ...    ...  ...   ...
# 5186  2017      1    2    16
# 5187  2017      1    2    19
# 5188  2017      1    3     9
# 5189  2017      1    3    11
# 5190  2017      1    3    18
#
# [5191 rows x 11 columns]

# %%
test_dataset = tf.data.Dataset.from_tensor_slices(df_test.values).batch(1)
for feat in test_dataset.take(5):
  print ('Features: {}'.format(feat))
# Out:
# Features: [[2.000e+00 9.300e+01 6.000e+00 3.000e+00 0.000e+00 1.000e+00 3.000e+00
#   2.015e+03 1.000e+00 4.000e+00 0.000e+00]]
# Features: [[2.500e+00 9.300e+01 5.000e+00 1.000e+00 0.000e+00 1.000e+00 3.000e+00
#   2.015e+03 1.000e+00 4.000e+00 1.000e+00]]
# Features: [[2.000e+00 1.000e+02 0.000e+00 1.000e+00 0.000e+00 1.000e+00 3.000e+00
#   2.015e+03 1.000e+00 4.000e+00 3.000e+00]]
# Features: [[0.000e+00 9.300e+01 6.500e+00 1.000e+00 0.000e+00 1.000e+00 3.000e+00
#   2.015e+03 1.000e+00 4.000e+00 4.000e+00]]
# Features: [[2.000e+00 9.300e+01 4.000e+00 1.000e+00 0.000e+00 1.000e+00 3.000e+00
#   2.015e+03 1.000e+00 4.000e+00 5.000e+00]]

# %%
prediction = model.predict(test_dataset)

# %%
df2['cnt']=prediction
df2
# Out:
#                timestamp   t1   t2    hum  wind_speed  weather_code  \
# 0    2015-01-04 00:00:00  3.0  2.0   93.0         6.0           3.0
# 1    2015-01-04 01:00:00  3.0  2.5   93.0         5.0           1.0
# 2    2015-01-04 03:00:00  2.0  2.0  100.0         0.0           1.0
# 3    2015-01-04 04:00:00  2.0  0.0   93.0         6.5           1.0
# 4    2015-01-04 05:00:00  2.0  2.0   93.0         4.0           1.0
# ...                  ...  ...  ...    ...         ...           ...
# 5186 2017-01-02 16:00:00  5.0  2.5   76.0        11.0           1.0
# 5187 2017-01-02 19:00:00  3.0  0.0   81.0        11.0           1.0
# 5188 2017-01-03 09:00:00  2.5 -1.5   81.0        14.0           1.0
# 5189 2017-01-03 11:00:00  4.0  0.0   78.0        21.0           1.0
# 5190 2017-01-03 18:00:00  5.0  1.0   81.0        22.0           2.0
#
#       is_holiday  is_weekend  season  year  month  day  hour          cnt
# 0            0.0         1.0     3.0  2015      1    4     0   405.224823
# 1            0.0         1.0     3.0  2015      1    4     1   309.454895
# 2            0.0         1.0     3.0  2015      1    4     3    79.884674
# 3            0.0         1.0     3.0  2015      1    4     4   125.285057
# 4            0.0         1.0     3.0  2015      1    4     5   101.978416
# ...          ...         ...     ...   ...    ...  ...   ...          ...
# 5186         1.0         0.0     3.0  2017      1    2    16  1102.733032
# 5187         1.0         0.0     3.0  2017      1    2    19   393.207184
# 5188         0.0         0.0     3.0  2017      1    3     9  1754.050659
# 5189         0.0         0.0     3.0  2017      1    3    11   666.676514
# 5190         0.0         0.0     3.0  2017      1    3    18  2221.027832
#
# [5191 rows x 14 columns]

# %%
output = df2.drop(['t1','t2','hum','wind_speed','weather_code','is_holiday','is_weekend','season','year','month','day','hour'], axis=1)

# %% [markdown]
# The CSV document of results is uploaded to Kaggle for evaluated.

# %%
output.to_csv('output_32_128_128_64_1_001xe0.1xepoch4-2_min_loss_32.csv',index=False)

# %% [markdown]
# The model is saved in h5 format.

# %%
model.save("32_128_128_64_1_001xe0.1xepoch4-2_min_loss_32.h5")
